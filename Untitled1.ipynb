# %%
n=1
m=100
for i in range(n,m+1):
  if (i % 3 ==0):
    print("Three")
  elif (i % 5 ==0):
    print("Five")
  elif (i % 5 ==0 and i % 3 ==0):
    print ("ThreeFive")
  else:
    print (i)
# Out:
# 1
# 2
# Three
# 4
# Five
# Three
# 7
# 8
# Three
# Five
# 11
# Three
# 13
# 14
# Three
# 16
# 17
# Three
# 19
# Five
# Three
# 22
# 23
# Three
# Five
# 26
# Three
# 28
# 29
# Three
# 31
# 32
# Three
# 34
# Five
# Three
# 37
# 38
# Three
# Five
# 41
# Three
# 43
# 44
# Three
# 46
# 47
# Three
# 49
# Five
# Three
# 52
# 53
# Three
# Five
# 56
# Three
# 58
# 59
# Three
# 61
# 62
# Three
# 64
# Five
# Three
# 67
# 68
# Three
# Five
# 71
# Three
# 73
# 74
# Three
# 76
# 77
# Three
# 79
# Five
# Three
# 82
# 83
# Three
# Five
# 86
# Three
# 88
# 89
# Three
# 91
# 92
# Three
# 94
# Five
# Three
# 97
# 98
# Three
# Five

# %%
liste=[1,2,3,4,5,6,8]
l=len(liste)
i=0
while (i<(l-1)):
  if(liste[i+1] != (liste[i]+1) ):
    print (liste[i]+1)
  i=i+1
# Out:
# 7

# %%
import numpy as np
def distance(v1, v2):
    return np.sqrt(np.sum((v1 - v2) ** 2))    

distance

# %%
def clean_cat_one_category(x):
 ch=x.get('idappcat')
# a=[]
# for i in d:
 # a.append(i)
 #ch=a[0]

 #cha=ch.split(', ')
 if "NULL" in ch:
  ch=ch.replace(",NULL","")
 #ch2 = "".join(cha)   
 mon_dictionnaire = {}
 mon_dictionnaire['idappcat'] ="ch"
 mon_dictionnaire['refproduitenseigne'] =x.get('refproduitenseigne')
 mon_dictionnaire['libelle'] =x.get('libelle')
 mon_dictionnaire['categorieenseigne'] =x.get('categorieenseigne')
 return mon_dictionnaire 

def clean_all(product_list):
  liste2=[]
  for i in product_list:
    liste2.append(clean_cat_one_category(i))
  return liste2
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-2cfa51dd42b7> in <module>
#       1 x=np.array(3)
# ----> 2 print(x[1])
#
# IndexError: too many indices for array

# %%
import json
with open ('products.json',encoding="utf8") as f:
  product_list=json.load(f)
print(product_list)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
product_list[3]
# Out:
# {'idappcat': '2076,3B,19C,138D,NULL,NULL',
#  'refproduitenseigne': 1146813,
#  'libelle': 'Champignons de Paris ?minc?s Bio 230g',
#  'categorieenseigne': 'boutique Epicerie | Conserves lÃ©gumes'}

# %%
def clean_cat_one_category(x):
 ch=x.get('idappcat')
# a=[]
# for i in d:
 # a.append(i)
 #ch=a[0]

 #cha=ch.split(', ')
 if "NULL" in ch:
  ch=ch.replace(",NULL","")
 #ch2 = "".join(cha)   
 mon_dictionnaire = {}
 mon_dictionnaire['idappcat'] =ch
 mon_dictionnaire['refproduitenseigne'] =x.get('refproduitenseigne')
 mon_dictionnaire['libelle'] =x.get('libelle')
 mon_dictionnaire['categorieenseigne'] =x.get('categorieenseigne')
 return mon_dictionnaire 

def clean_all(product_list):
  liste2=[]
  for i in product_list:
    liste2.append(clean_cat_one_category(i))
  return liste2
clean_all(product_list)
# Out:
# [{'idappcat': '2076,3B,19C,138D',
#   'refproduitenseigne': 364980,
#   'libelle': 'Nature bio champignons émincés 230g ',
#   'categorieenseigne': ''},
#  {'idappcat': '2076,3B,19C,138D',
#   'refproduitenseigne': 775971,
#   'libelle': 'Nature bio champignons émincés 230g ',
#   'categorieenseigne': 'Champignons, Tomates, Marrons | epicerie salee | conserves de legumes | champignons tomates marrons'},
#  {'idappcat': '2076,3B,19C,138D',
#   'refproduitenseigne': 1014904,
#   'libelle': 'Champignons de Paris 230 g 230 g',
#   'categorieenseigne': 'Boutique thématique | Le salé'},
#  {'idappcat': '2076,3B,19C,138D',
#   'refproduitenseigne': 1146813,
#   'libelle': 'Champignons de Paris ?minc?s Bio 230g',
#   'categorieenseigne': 'boutique Epicerie | Conserves lÃ©gumes'},
#  {'idappcat': '2076,3B,19C,138D',
#   'refproduitenseigne': 374888,
#   'libelle': 'Borde garniture de champignons pour volaille bocalook 90g ',
# ...

# %%
  x=product_list[1]
  ch=x.get('idappcat')
  cha=ch.split(', ')
  l=cha.reverse()
  print (type(cha))
  texte = "".join(l)
# Out:
# <class 'list'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-7cff4b5883de> in <module>
#       4 l=cha.reverse()
#       5 print (type(cha))
# ----> 6 texte = "".join(l)
#
# TypeError: can only join an iterable
